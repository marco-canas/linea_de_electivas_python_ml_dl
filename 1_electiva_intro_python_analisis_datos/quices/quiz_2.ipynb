# %% [markdown]
# Este es un diseño **alineado al cronograma**, con foco en **pensamiento algorítmico**, **lectura de código** y **uso correcto de estructuras de control**, que es justo donde suele aparecer la primera “curva” cognitiva del curso.
#
# ---
#
# # Quiz 2 – Fundamentos de Programación
#
# **Curso:** Fundamentos de Programación
# **Código:** 314029
#
# **Fecha de realización:** **jueves 26 de marzo de 2026**
# **Horario:** 8:00 a.m. – 12:00 m. (se sugiere aplicar el quiz en los primeros 30 minutos)
# ⏱ **Duración del quiz:** 30 minutos
# **Modalidad:** Individual
# **Entorno:** Jupyter Notebook
# **Valor sugerido:** 5% de la nota final
#
# ---
#
# ##  Contenidos evaluados
#
# **Capítulos 4, 5 y 6**
#
# * Expresiones condicionales (`if`, `elif`, `else`)
# * Operadores lógicos
# * Bucles (`for`, `while`, `else` en bucles)
# * Funciones
# * Tipos de argumentos
# * Funciones lambda
# * `map()`, `filter()`
#
# ---
#
# ## 🎯 Objetivos del Quiz
#
# * Evaluar la **comprensión de la lógica condicional**.
# * Verificar el manejo de **estructuras repetitivas**.
# * Analizar la capacidad de **leer y razonar código Python**.
# * Valorar el uso básico de **funciones** como abstracción.
#
# ---
#
# ## 📌 Preguntas
#
# ### **Pregunta 1 – Selección múltiple (1.0 punto)**
#
# ¿Cuál de las siguientes expresiones evalúa correctamente si un número `x` está entre 0 y 10 (incluidos)?
#
# A. `if x > 0 or x < 10:`
# B. `if 0 <= x <= 10:`
# C. `if x >= 0 or x <= 10:`
# D. `if x > 0 and < 10:`
#
# 👉 Seleccione una sola opción correcta.
#
# ---
#
# ### **Pregunta 2 – Verdadero / Falso (1.0 punto)**
#
# Indique si las afirmaciones son **Verdaderas (V)** o **Falsas (F)**. Justifique brevemente las falsas.
#
# a) En Python, la indentación no afecta la ejecución del programa.
# b) Un bucle `for` puede recorrer una lista de números.
# c) Un bucle `while` se ejecuta siempre al menos una vez.
# d) La cláusula `else` en un bucle se ejecuta cuando el bucle termina sin usar `break`.
#
# ---
#
# ### **Pregunta 3 – Lectura de código (1.0 punto)**
#
# ```python
# for i in range(1, 6):
#     if i % 2 == 0:
#         print(i)
# ```
#
# a) ¿Qué números se imprimen en pantalla?
# b) ¿Cuántas veces se ejecuta el cuerpo del bucle?
#
# ---
#
# ### **Pregunta 4 – Funciones (1.0 punto)**
#
# Considere la siguiente función:
#
# ```python
# def cuadrado(x):
#     return x * x
# ```
#
# a) ¿Qué valor retorna `cuadrado(5)`?
# b) ¿Qué tipo de argumento recibe la función?
# c) ¿Qué ventaja tiene usar una función en lugar de repetir el cálculo varias veces?
#
# ---
#
# ### **Pregunta 5 – Práctica guiada (1.0 punto)**
#
# En una celda de Jupyter Notebook:
#
# 1. Cree una **función lambda** que reciba un número y retorne `True` si es par y `False` si es impar.
# 2. Use la función `filter()` para obtener solo los números pares de la lista:
#
# ```python
# numeros = [1, 2, 3, 4, 5, 6, 7, 8]
# ```
#
# 3. Muestre el resultado en pantalla.
#
# ---
#
# ## 📊 Rúbrica de evaluación
#
# | Criterio           | Excelente (1.0)                | Aceptable (0.6)           | Insuficiente (0.0) |
# | ------------------ | ------------------------------ | ------------------------- | ------------------ |
# | Lógica condicional | Condiciones correctas y claras | Error menor               | Incorrecta         |
# | Bucles             | Comprensión completa           | Comprensión parcial       | No comprende       |
# | Lectura de código  | Interpreta y explica           | Interpreta parcialmente   | No interpreta      |
# | Uso de funciones   | Función correcta y clara       | Función con errores leves | No funcional       |
#
# ---
#
# ## 🧠 Observación didáctica
#
# Este Quiz 2:
#
# * Marca el paso de **“aprender sintaxis” a “pensar algorítmicamente”**.
# * Prepara muy bien a los estudiantes para el **Parcial 2**.
# * Detecta temprano dificultades con **condiciones compuestas** y **bucles**.
#
# Si quieres, en el siguiente mensaje puedo:
#
# * ✔️ darte el **solucionario oficial**
# * ✔️ convertirlo en **quiz automático en Jupyter**
# * ✔️ ajustarlo para **nivel Licenciatura / Ingeniería / Administración**
# * ✔️ alinearlo con una **rúbrica institucional UdeA**
#
# Seguimos 🚀
