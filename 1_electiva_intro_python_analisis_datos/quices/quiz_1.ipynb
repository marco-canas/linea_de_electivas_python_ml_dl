# %% [markdown]
# Este es un **Quiz 1** coherente con el **inicio del curso**, enfocado en **comprensión conceptual**, **lectura de código** y **primer contacto con Python**, sin ser excesivamente técnico (ideal para estudiantes que apenas arrancan).
#
# Este **Quiz 1** evalúa principalmente **Capítulos 1 y 2** y un toque introductorio del **Capítulo 3**.
#
# ---
#
# # Quiz 1 – Fundamentos de Programación
#
# **Curso:** Fundamentos de Programación
# **Código:** 314029
# **Duración:** 30 minutos
# **Modalidad:** Individual
# **Formato:** Teórico–práctico (conceptual + lectura de código)
# **Herramientas permitidas:**
#
# * Jupyter Notebook
# * Python Shell
# * Apuntes personales
#
# **Valor sugerido:** 5% de la nota final
#
# ---
#
# # Objetivos del Quiz
#
# * Reconocer las **características fundamentales de Python**.
# * Verificar la **comprensión del entorno de desarrollo** (Anaconda, Shell, Jupyter).
# * Interpretar **instrucciones básicas en Python**.
# * Identificar **tipos de datos simples** y salidas de código.
#
# ---
#
# # Preguntas
#
# ### **Pregunta 1 – Selección múltiple (1.0 punto)**
#
# Python es considerado un lenguaje:
#
# A. Compilado, de bajo nivel y monolítico
# B. Interpretado, de alto nivel y multiparadigma
# C. Exclusivo para análisis de datos
# D. Fuertemente tipado y no interactivo
#
# - **Seleccione una sola respuesta correcta.**
#
# ---
#
# ### **Pregunta 2 – Verdadero / Falso (1.0 punto)**
#
# Indique si las siguientes afirmaciones son **Verdaderas (V)** o **Falsas (F)**. Justifique **brevemente** las falsas.
#
# a) Python es un lenguaje de código cerrado.
# b) Jupyter Notebook permite combinar código, texto y visualizaciones.
# c) El Python Shell funciona bajo el esquema REPL.
# d) Anaconda solo sirve para programar en Python desde la terminal.
#
# ---
#
# ### **Pregunta 3 – Respuesta corta (1.0 punto)**
#
# Explique **dos diferencias** entre ejecutar código en:
#
# * Python Shell
# * Jupyter Notebook
#
# (No más de 4 líneas)
#
# ---
#
# ### **Pregunta 4 – Lectura de código (1.0 punto)**
#
# Observe el siguiente código escrito en el Python Shell:
#
# ```python
# x = 10
# y = 3
# print(x + y)
# print(type(x))
# ```
#
# Responda:
#
# a) ¿Qué se imprime en pantalla?
# b) ¿Qué tipo de dato tiene la variable `x`?
#
# ---
#
# # **Pregunta 5 – Práctica básica (1.0 punto)**
#
# En una celda de Jupyter Notebook:
#
# 1. Cree una variable llamada `nombre` que almacene su nombre.
# 2. Cree una variable llamada `edad` que almacene su edad.
# 3. Imprima en pantalla un mensaje como:
#
# > "Mi nombre es ___ y tengo ___ años."
#
# (Use la función `print()`)
#
# ---
#
# # Rúbrica de evaluación
#
# | Criterio              | Excelente (1.0)               | Aceptable (0.6)            | Insuficiente (0.0)   |
# | --------------------- | ----------------------------- | -------------------------- | -------------------- |
# | Conceptos de Python   | Respuestas claras y correctas | Ideas parciales            | Incorrectas          |
# | Entorno de desarrollo | Diferencias bien explicadas   | Explicación superficial    | Confusa o incorrecta |
# | Lectura de código     | Interpreta correctamente      | Error menor                | No interpreta        |
# | Uso básico de Python  | Código funcional y claro      | Funciona con errores leves | No ejecuta           |
#
# ---
#
# # Observación didáctica
#
# Este quiz:
#
# * No castiga la falta de experiencia previa.
# * Evalúa **comprensión**, no memoria.
# * Refuerza el uso temprano de **Jupyter Notebook**, alineado con tu enfoque de aula invertida.
