# %% [markdown]
# ¡Vamos con el **Quiz 3**, profe! 📊🐍
# Este ya entra en terreno **aplicado**, donde Python deja de ser “lenguaje” y se vuelve **herramienta para trabajar datos**, así que el diseño apunta a **I/O + Pandas + pensamiento de análisis**.
#
# ---
#
# # 📝 Quiz 3 – Fundamentos de Programación
#
# **Curso:** Fundamentos de Programación
# **Código:** 314029
#
# 📅 **Fecha de realización:** **jueves 23 de abril de 2026**
# ⏰ **Horario:** 8:00 a.m. – 12:00 m.
# 🕒 **Duración del quiz:** 30 minutos
# 👤 **Modalidad:** Individual
# 💻 **Entorno:** Jupyter Notebook
# 📊 **Valor sugerido:** 5% de la nota final
#
# ---
#
# # Contenidos evaluados
#
# **Capítulos 7, 8 y 9**
#
# * Archivos en Python (I/O)
# * Conceptos básicos de análisis de datos
# * Estructuras de datos tabulares
# * Introducción a **Pandas**
#
#   * DataFrame
#   * Carga de datos
#   * Exploración
#   * Selección
#   * Limpieza básica
#
# ---
#
# # Objetivos del Quiz
#
# * Verificar el manejo básico de **lectura y escritura de archivos**.
# * Evaluar la comprensión del **proceso de análisis de datos**.
# * Comprobar el uso elemental de **Pandas** para explorar datos.
# * Fomentar la lectura e interpretación de resultados tabulares.
#
# ---
#
# # Preguntas
#
# ---
#
# ### **Pregunta 1 – Selección múltiple (1.0 punto)**
#
# ¿Cuál de las siguientes opciones describe mejor un **DataFrame** en Pandas?
#
# A. Una lista de listas
# B. Una estructura de datos bidimensional con filas y columnas
# C. Un arreglo unidimensional
# D. Un archivo externo de datos
#
# - Seleccione una sola respuesta correcta.
#
# ---
#
# ### **Pregunta 2 – Verdadero / Falso (1.0 punto)**
#
# Indique si las afirmaciones son **Verdaderas (V)** o **Falsas (F)**. Justifique brevemente las falsas.
#
# a) En Python, un archivo debe abrirse antes de poder leerse o escribirse.
# b) `pandas.read_csv()` permite cargar datos desde un archivo CSV.
# c) El análisis descriptivo busca predecir lo que ocurrirá en el futuro.
# d) Un DataFrame puede tener columnas de distintos tipos de datos.
#
# ---
#
# ### **Pregunta 3 – Lectura de código (1.0 punto)**
#
# Considere el siguiente código:
#
# ```python
# import pandas as pd
#
# data = {
#     'Nombre': ['Ana', 'Luis', 'Carlos'],
#     'Edad': [20, 25, 30]
# }
#
# df = pd.DataFrame(data)
# print(df.head(2))
# ```
#
# a) ¿Cuántas filas se imprimen en pantalla?
# b) ¿Cuántas columnas tiene el DataFrame?
# c) ¿Qué información contiene cada fila?
#
# ---
#
# ### **Pregunta 4 – Archivos (1.0 punto)**
#
# Responda de forma corta:
#
# a) ¿Para qué sirve la instrucción `with open("archivo.txt", "r") as f:`?
# b) Mencione **una ventaja** de usar la estructura `with` al trabajar con archivos.
#
# ---
#
# ### **Pregunta 5 – Práctica guiada con Pandas (1.0 punto)**
#
# En una celda de Jupyter Notebook:
#
# 1. Cree un DataFrame llamado `estudiantes` con la siguiente información:
#
# | Nombre | Nota |
# | ------ | ---- |
# | Ana    | 4.5  |
# | Luis   | 3.8  |
# | Carlos | 4.2  |
#
# 2. Muestre:
#
#    * Las primeras filas del DataFrame.
#    * El promedio de la columna `Nota`.
#
# *(Puede usar `mean()`)*
#
# ---
#
# ## Rúbrica de evaluación
#
# | Criterio                       | Excelente (1.0)                | Aceptable (0.6)            | Insuficiente (0.0) |
# | ------------------------------ | ------------------------------ | -------------------------- | ------------------ |
# | Manejo de archivos             | Concepto claro                 | Idea parcial               | Incorrecto         |
# | Conceptos de análisis de datos | Correctos y bien interpretados | Superficiales              | Incorrectos        |
# | Uso de Pandas                  | DataFrame correcto y funcional | Funciona con errores leves | No funciona        |
# | Lectura de resultados          | Interpreta correctamente       | Interpreta parcialmente    | No interpreta      |
#
# ---
#
# ## Observación didáctica
#
# Este **Quiz 3**:
#
# * Marca el paso de **programar → analizar datos**.
# * Prepara directamente el terreno para **NumPy y Matplotlib**.
# * Permite detectar dificultades tempranas con **DataFrames** antes del Parcial 3.
