# %% [markdown]
# # 🧠📘 Cuaderno Jupyter: Monitoreo de Terapia Cognitivo-Conductual (TCC)
#
# Este cuaderno permite monitorear principios de TCC para potenciar el tratamiento con **bupropión**.

# %%
import pandas as pd
from datetime import date

hoy = date.today()
hoy

# %% [markdown]
# ## Activación conductual

# %%
activacion = pd.DataFrame(columns=[
    'fecha','actividad','tipo','dificultad (0-10)','realizada','sensacion_posterior'
])
activacion

# %% [markdown]
# ## Registro de pensamientos automáticos

# %%
pensamientos = pd.DataFrame(columns=[
    'fecha','situacion','pensamiento_automatico','emocion','intensidad (0-100)','pensamiento_alternativo'
])
pensamientos

# %% [markdown]
# ## Sueño

# %%
sueno = pd.DataFrame(columns=[
    'fecha','hora_acostarse','hora_levantarse','horas_sueno','calidad (0-10)','observaciones'
])
sueno

# %% [markdown]
# ## Avances

# %%
avances = pd.DataFrame(columns=[
    'fecha','logro','dificultad_superada','aprendizaje'
])
avances
